# %% [markdown]
# <a href="https://colab.research.google.com/github/RUBAN-waq/Spam_SMS_Detection/blob/main/sms1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("spam.csv", encoding='latin-1')

df = df[['v1','v2']]
df.columns=['label','message']

df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['label']=df['label'].map({'ham':0,'spam':1})

# %%
X_train,X_test,y_train,y_test=train_test_split(
    df['message'],
    df['label'],
    test_size=0.2,
    random_state=42
)

# %%
tfidf=TfidfVectorizer(stop_words='english')

X_train_tfidf=tfidf.fit_transform(X_train)

X_test_tfidf=tfidf.transform(X_test)

# %%
nb=MultinomialNB()

nb.fit(X_train_tfidf,y_train)

pred_nb=nb.predict(X_test_tfidf)

print("Accuracy:",accuracy_score(y_test,pred_nb))

print(classification_report(y_test,pred_nb))
# Out:
# Accuracy: 0.9668161434977578
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       965
#            1       1.00      0.75      0.86       150
#
#     accuracy                           0.97      1115
#    macro avg       0.98      0.88      0.92      1115
# weighted avg       0.97      0.97      0.96      1115

# %%
lr=LogisticRegression()

lr.fit(X_train_tfidf,y_train)

pred_lr=lr.predict(X_test_tfidf)

print("Accuracy:",accuracy_score(y_test,pred_lr))
# Out:
# Accuracy: 0.9524663677130045

# %%
svm=LinearSVC()

svm.fit(X_train_tfidf,y_train)

pred_svm=svm.predict(X_test_tfidf)

print("Accuracy:",accuracy_score(y_test,pred_svm))
# Out:
# Accuracy: 0.97847533632287

# %%
sms=["Congratulations! You won a free iPhone. Click here."]

sms_tfidf=tfidf.transform(sms)

prediction=svm.predict(sms_tfidf)

if prediction[0]==1:
    print("Spam")
else:
    print("Legitimate")
# Out:
# Spam

# %%
sms=["Are you coming to college tomorrow?"]
